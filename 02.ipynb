# %%
from PIL import Image
from imgtools import *

# %%
my_dir = 'C:/Users/DELL/Documents/TGMT_Image'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (275, 183)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
# (215, 235)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=215x235>
# (500, 332)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x332>
# (198, 254)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=198x254>
# (300, 168)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>
