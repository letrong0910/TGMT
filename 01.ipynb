# %%
# Ctrl + Enter : Run code
# Shift + Enter : run code => them mot dong moi

# %%
#Import thư viện 
from PIL import Image

# %%
#thư mục chứa hình ảnh 
dir = 'C:/Users/DELL/Documents/TGMT_Image'

# %%
#Đường dẫn hình ảnh
image_path = dir + '/bautroi.jpg'
print(image_path)
# Out:
# C:/Users/DELL/Documents/TGMT_Image/bautroi.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (275, 183)
